# %% [markdown]
# # Outlier or Catilin Clark? A Data Science Project
# ## Part 2 - Data Cleaning and Preprocessing
#
# This notebook contains the code for the second part of this data science project - data cleaning and preprocessing. Section headings have been included for convenience and the full writeup is available [on my website](https://www.pineconedata.com/2024-05-02-basketball-data-cleaning-preprocessing/).
#
# In summary, there will be a notebook (and post) for each part of the process - from initial steps like data acquisition, preprocessing, and cleaning to more advanced steps like feature engineering, machine learning, and creating visualizations. The dataset used in this project contains individual basketball player statistics (such as total points scored and blocks made) for the 2023-2024 NCAA women’s basketball season.

# %% [markdown]
# # Getting Started
# Full requirements and environment setup information is detailed in the [full blog post](https://www.pineconedata.com/2024-04-11-basketball-data-acquisition/).
#
# ## Import Packages

# %%
import pandas as pd
import requests
import json
import os
import numpy as np
import openpyxl

# %% [markdown]
# ## Import Data

# %%
player_data = pd.read_excel('player_data_raw.xlsx')
player_data.head()
# Out:
#          PLAYER_NAME                           Team Class Height Position  \
# 0      Kiara Jackson           UNLV (Mountain West)   Jr.    5-7        G
# 1      Raven Johnson           South Carolina (SEC)   So.    5-8        G
# 2        Gina Marxen              Montana (Big Sky)   Sr.    5-8        G
# 3  McKenna Hofschild   Colorado St. (Mountain West)   Sr.    5-2        G
# 4        Kaylah Ivey           Boston College (ACC)   Jr.    5-8        G
#
#        PLAYER_ID       TEAM_NAME  GAMES  MINUTES_PLAYED  FIELD_GOALS_MADE  \
# 0  ncaaw.p.67149            UNLV     29             895               128
# 1  ncaaw.p.67515  South Carolina     30             823                98
# 2  ncaaw.p.57909         Montana     29             778                88
# 3  ncaaw.p.60402    Colorado St.     29            1046               231
# 4  ncaaw.p.64531    Boston Coll.     33             995                47
#
#    ...  FREE_THROW_PERCENTAGE  OFFENSIVE_REBOUNDS  DEFENSIVE_REBOUNDS  \
# 0  ...                   75.0                  27                 102
# 1  ...                   64.3                  33                 128
# 2  ...                   72.4                   6                  54
# 3  ...                   83.5                   6                 109
# 4  ...                   60.7                  12                  45
#
#    TOTAL_REBOUNDS  ASSISTS  TURNOVERS  STEALS  BLOCKS  FOULS  POINTS
# 0             129      135         42      31       5     47     323
# 1             161      148         53      60       5     34     243
# 2              60      111         38      16       2     26     297
# 3             115      211         71      36       4     34     654
# 4              57      186         64      36       1     48     143
#
# [5 rows x 27 columns]

# %% [markdown]
# # Data Cleaning
#
# ## Handle Missing Values
#
# ### Identify Missing Values

# %%
player_data[player_data.isna().any(axis=1)]
# Out:
#            PLAYER_NAME                        Team Class Height Position  \
# 148         Ally Becki              Ball St. (MAC)   Jr.    5-8      NaN
# 245     Caitlin Weimar         Boston U. (Patriot)   Sr.    6-4        F
# 250          Abby Muse   Boise St. (Mountain West)   Sr.    6-2        F
# 254       Emily Bowman             Samford (SoCon)   So.    6-5        C
# 257    Christina Dalce        Villanova (Big East)   Jr.    6-2        F
# ..                 ...                         ...   ...    ...      ...
# 726    Kseniia Kozlova    James Madison (Sun Belt)   Sr.    6-3        C
# 727  Simone Cunningham     Old Dominion (Sun Belt)   Jr.   5-10        G
# 729  Otaifo Esenabhalu        Longwood (Big South)   Fr.    6-2        F
# 755     Sedayjha Payne           Morgan St. (MEAC)   Sr.    5-8        G
# 843   Madelyn Bischoff              Ball St. (MAC)   Jr.    5-9      NaN
#
#           PLAYER_ID      TEAM_NAME  GAMES  MINUTES_PLAYED  FIELD_GOALS_MADE  \
# 148   ncaaw.p.66590       Ball St.     31             972               143
# 245   ncaaw.p.64464     N.C. State     28             987               199
# 250   ncaaw.p.64516      Boise St.     31             785                90
# 254   ncaaw.p.64719        Samford     30             703                89
# 257   ncaaw.p.67708      Villanova     30             833               108
# ..              ...            ...    ...             ...               ...
# 726   ncaaw.p.64131  James Madison     24             526               118
# 727  ncaaw.p.113163   Old Dominion     30             591                84
# 729  ncaaw.p.113170       Longwood     30             547                60
# 755  ncaaw.p.113276     Morgan St.     29             634                80
# 843   ncaaw.p.66600       Ball St.     30             881               112
#
#      ...  FREE_THROW_PERCENTAGE  OFFENSIVE_REBOUNDS  DEFENSIVE_REBOUNDS  \
# 148  ...                   75.4                  21                 122
# 245  ...                   68.4                  76                 219
# 250  ...                   54.3                  74                 191
# 254  ...                   53.1                  83                 172
# 257  ...                   54.9                 145                 146
# ..   ...                    ...                 ...                 ...
# 726  ...                   57.1                  74                  97
# 727  ...                   56.5                  87                 123
# 729  ...                   60.0                  79                 128
# 755  ...                   52.0                  66                  73
# 843  ...                   86.6                  11                  60
#
#      TOTAL_REBOUNDS  ASSISTS  TURNOVERS  STEALS  BLOCKS  FOULS  POINTS
# 148             143      148        108      60      11     69     398
# 245             295       54         69      37      80     74     519
# 250             265       34         66      36      87     72     230
# 254             255       17         55       5      74     88     238
# 257             291       30         52      25      70     89     255
# ..              ...      ...        ...     ...     ...    ...     ...
# 726             171       19         51       8       8     55     284
# 727             210       12         60      20      21     93     207
# 729             207       10         59      23      13     78     147
# 755             139       24         53      67       7     58     186
# 843              71       37         36      20       6     38     359
#
# [63 rows x 27 columns]

# %%
player_data.columns[player_data.isna().any()].tolist()
# Out:
# ['Position', 'THREE_POINT_PERCENTAGE']

# %%
player_data[player_data.isna().any(axis=1)][['PLAYER_NAME', 'Team', 'Position', 'THREE_POINT_PERCENTAGE']]
# Out:
#            PLAYER_NAME                        Team Position  \
# 148         Ally Becki              Ball St. (MAC)      NaN
# 245     Caitlin Weimar         Boston U. (Patriot)        F
# 250          Abby Muse   Boise St. (Mountain West)        F
# 254       Emily Bowman             Samford (SoCon)        C
# 257    Christina Dalce        Villanova (Big East)        F
# ..                 ...                         ...      ...
# 726    Kseniia Kozlova    James Madison (Sun Belt)        C
# 727  Simone Cunningham     Old Dominion (Sun Belt)        G
# 729  Otaifo Esenabhalu        Longwood (Big South)        F
# 755     Sedayjha Payne           Morgan St. (MEAC)        G
# 843   Madelyn Bischoff              Ball St. (MAC)      NaN
#
#      THREE_POINT_PERCENTAGE
# 148                    34.8
# 245                     NaN
# 250                     NaN
# 254                     NaN
# 257                     NaN
# ..                      ...
# 726                     NaN
# 727                     NaN
# 729                     NaN
# 755                     NaN
# 843                    40.3
#
# [63 rows x 4 columns]

# %% [markdown]
# ### Handle Missing Three-Point Percentages

# %%
player_data[player_data['THREE_POINT_PERCENTAGE'].isna()][['PLAYER_NAME', 'Team', 'Position', 'THREE_POINTS_MADE', 'THREE_POINT_ATTEMPTS', 'THREE_POINT_PERCENTAGE']]
# Out:
#            PLAYER_NAME                               Team Position  \
# 245     Caitlin Weimar                Boston U. (Patriot)        F
# 250          Abby Muse          Boise St. (Mountain West)        F
# 254       Emily Bowman                    Samford (SoCon)        C
# 257    Christina Dalce               Villanova (Big East)        F
# 258     Emily Saunders           Youngstown St. (Horizon)        F
# 264       Lauren Betts                      UCLA (Pac-12)        C
# 265      Tenin Magassa         Rhode Island (Atlantic 10)        C
# 275     Brooklyn Meyer   South Dakota St. (Summit League)        F
# 282   Breya Cunningham                   Arizona (Pac-12)        F
# 290    Rochelle Norris                Central Mich. (MAC)        C
# 296       Rita Igbokwe                     Ole Miss (SEC)        F
# 297     Kyndall Golden                Kennesaw St. (ASUN)        F
# 306     Kennedy Basham                    Oregon (Pac-12)        F
# 307      Maria Gakdeng               North Carolina (ACC)        C
# 311        Kate Samson                     Navy (Patriot)        C
# 316         Liatu King                   Pittsburgh (ACC)        F
# 318       Ashlee Lewis       Cal St. Fullerton (Big West)        C
# 319     Jillian Archer         St. John's (NY) (Big East)        F
# 322       Kylee Watson                   Notre Dame (ACC)        F
# 326     Caitlin Staley                 Western Ky. (CUSA)        F
# 332   Sacha Washington                   Vanderbilt (SEC)        F
# 340    Adreanna Waddle                Prairie View (SWAC)        F
# 348      River Baldwin                     NC State (ACC)        C
# 353      Zyheima Swint                      Hofstra (CAA)        C
# 355    Phillipina Kyei                    Oregon (Pac-12)        C
# 358       Jasmin Dixon       Northwestern St. (Southland)        F
# 361      Shamarre Hale                 Austin Peay (ASUN)        C
# 366      Jadyn Donovan                         Duke (ACC)        G
# 367     Melyia Grayson          Southern Miss. (Sun Belt)        C
# 379     ZiKeyah Carter       Chicago St. (DI Independent)        C
# 380     Meghan Downing                       ETSU (SoCon)        F
# 394     Makayla Minett             Denver (Summit League)        F
# 401      Ugonne Onyiah                California (Pac-12)        F
# 402   Bella Murekatete            Washington St. (Pac-12)        C
# 409        Zoe McCrary           Col. of Charleston (CAA)        F
# 411       Ashlee Locke                     Mercer (SoCon)        F
# 414          Kyra Wood                     Syracuse (ACC)        F
# 420        Laura Bello                Idaho St. (Big Sky)        F
# 424        Khalis Cain             UNC Greensboro (SoCon)        F
# 428   Hannah Noveroske                       Toledo (MAC)        C
# 431  Yaubryon Chambers               Tennessee Tech (OVC)        F
# 433  Sierra McCullough                 Eastern Ky. (ASUN)        F
# 437       India Howard                  North Ala. (ASUN)        F
# 440        Kayla Clark             Bethune-Cookman (SWAC)        C
# 443      Katlyn Manuel                     ULM (Sun Belt)        F
# 445     Jordana Reisma            Cleveland St. (Horizon)        F
# 462          Carys Roy               Saint Peter's (MAAC)        C
# 468   Clarice Akunwafo       Southern California (Pac-12)        C
# 526      Carter McCray             Northern Ky. (Horizon)        C
# 548         Ajae Petty                     Kentucky (SEC)        F
# 664     Ellie Mitchell             Princeton (Ivy League)        F
# 682     Teneisia Brown                          FDU (NEC)        F
# 686     Alancia Ramsey        Coastal Carolina (Sun Belt)        F
# 715     Chyna Cornwell                  Rutgers (Big Ten)        F
# 722     Kennedy Taylor                 Missouri St. (MVC)        F
# 726    Kseniia Kozlova           James Madison (Sun Belt)        C
# 727  Simone Cunningham            Old Dominion (Sun Belt)        G
# 729  Otaifo Esenabhalu               Longwood (Big South)        F
# 755     Sedayjha Payne                  Morgan St. (MEAC)        G
#
#      THREE_POINTS_MADE  THREE_POINT_ATTEMPTS  THREE_POINT_PERCENTAGE
# 245                  0                     0                     NaN
# 250                  0                     0                     NaN
# 254                  0                     0                     NaN
# 257                  0                     0                     NaN
# 258                  0                     0                     NaN
# 264                  0                     0                     NaN
# 265                  0                     0                     NaN
# 275                  0                     0                     NaN
# 282                  0                     0                     NaN
# 290                  0                     0                     NaN
# 296                  0                     0                     NaN
# 297                  0                     0                     NaN
# 306                  0                     0                     NaN
# 307                  0                     0                     NaN
# 311                  0                     0                     NaN
# 316                  0                     0                     NaN
# 318                  0                     0                     NaN
# 319                  0                     0                     NaN
# 322                  0                     0                     NaN
# 326                  0                     0                     NaN
# 332                  0                     0                     NaN
# 340                  0                     0                     NaN
# 348                  0                     0                     NaN
# 353                  0                     0                     NaN
# 355                  0                     0                     NaN
# 358                  0                     0                     NaN
# 361                  0                     0                     NaN
# 366                  0                     0                     NaN
# 367                  0                     0                     NaN
# 379                  0                     0                     NaN
# 380                  0                     0                     NaN
# 394                  0                     0                     NaN
# 401                  0                     0                     NaN
# 402                  0                     0                     NaN
# 409                  0                     0                     NaN
# 411                  0                     0                     NaN
# 414                  0                     0                     NaN
# 420                  0                     0                     NaN
# 424                  0                     0                     NaN
# 428                  0                     0                     NaN
# 431                  0                     0                     NaN
# 433                  0                     0                     NaN
# 437                  0                     0                     NaN
# 440                  0                     0                     NaN
# 443                  0                     0                     NaN
# 445                  0                     0                     NaN
# 462                  0                     0                     NaN
# 468                  0                     0                     NaN
# 526                  0                     0                     NaN
# 548                  0                     0                     NaN
# 664                  0                     0                     NaN
# 682                  0                     0                     NaN
# 686                  0                     0                     NaN
# 715                  0                     0                     NaN
# 722                  0                     0                     NaN
# 726                  0                     0                     NaN
# 727                  0                     0                     NaN
# 729                  0                     0                     NaN
# 755                  0                     0                     NaN

# %% [markdown]
# ### Handle Missing Positions

# %%
player_data[player_data['Position'].isna()][['PLAYER_NAME', 'Team', 'Position']]
# Out:
#           PLAYER_NAME                  Team Position
# 148        Ally Becki        Ball St. (MAC)      NaN
# 359      Marie Kiefer        Ball St. (MAC)      NaN
# 709        Ava Uhrich   Southern Utah (WAC)      NaN
# 843  Madelyn Bischoff        Ball St. (MAC)      NaN

# %%
player_data.loc[player_data['PLAYER_NAME'] == 'Ally Becki', 'Position'] = 'G'
player_data.loc[player_data['PLAYER_NAME'] == 'Marie Kiefer', 'Position'] = 'F'
player_data.loc[player_data['PLAYER_NAME'] == 'Ava Uhrich', 'Position'] = 'F'
player_data.loc[player_data['PLAYER_NAME'] == 'Madelyn Bischoff', 'Position'] = 'G'

# %%
player_data[player_data['Position'].isna()][['PLAYER_NAME', 'Team', 'Position']]
# Out:
# Empty DataFrame
# Columns: [PLAYER_NAME, Team, Position]
# Index: []

# %% [markdown]
# ## Handle Incorrect Values
#
# ### Handle Incorrect Heights

# %%
player_data['Height'].unique()
# Out:
# array(['5-7', '5-8', '5-2', '5-9', '5-6', '6-0', '5-10', '5-3', '5-11',
#        '5-5', '5-4', '6-2', '6-1', '6-3', '6-4', '6-6', '6-5', '6-7',
#        '6-8', '0-0'], dtype=object)

# %%
player_data[player_data['Height'].eq('0-0')]
# Out:
#      PLAYER_NAME                      Team Class Height Position  \
# 709   Ava Uhrich       Southern Utah (WAC)   Fr.    0-0        F
# 823  Payton Hull   Abilene Christian (WAC)   Fr.    0-0        G
#
#           PLAYER_ID          TEAM_NAME  GAMES  MINUTES_PLAYED  \
# 709  ncaaw.p.115529      Southern Utah     29             877
# 823  ncaaw.p.112709  Abilene Christian     29             837
#
#      FIELD_GOALS_MADE  ...  FREE_THROW_PERCENTAGE  OFFENSIVE_REBOUNDS  \
# 709               151  ...                   68.4                  65
# 823               155  ...                   75.3                  33
#
#      DEFENSIVE_REBOUNDS  TOTAL_REBOUNDS  ASSISTS  TURNOVERS  STEALS  BLOCKS  \
# 709                 149             214       47         55      22      19
# 823                  67             100       59         87      47       8
#
#      FOULS  POINTS
# 709     76     383
# 823     71     444
#
# [2 rows x 27 columns]

# %%
player_data.loc[player_data['PLAYER_NAME'] == 'Ava Uhrich', 'Height'] = '6-0'
player_data.loc[player_data['PLAYER_NAME'] == 'Payton Hull', 'Height'] = '5-11'

# %%
player_data[player_data.eq('0-0').any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [PLAYER_NAME, Team, Class, Height, Position, PLAYER_ID, TEAM_NAME, GAMES, MINUTES_PLAYED, FIELD_GOALS_MADE, FIELD_GOAL_ATTEMPTS, FIELD_GOAL_PERCENTAGE, THREE_POINTS_MADE, THREE_POINT_ATTEMPTS, THREE_POINT_PERCENTAGE, FREE_THROWS_MADE, FREE_THROW_ATTEMPTS, FREE_THROW_PERCENTAGE, OFFENSIVE_REBOUNDS, DEFENSIVE_REBOUNDS, TOTAL_REBOUNDS, ASSISTS, TURNOVERS, STEALS, BLOCKS, FOULS, POINTS]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ### Handle Incorrect Classes

# %%
player_data['Class'].unique()
# Out:
# array(['Jr.', 'So.', 'Sr.', 'Fr.', '---'], dtype=object)

# %%
player_data[player_data['Class'] == '---']
# Out:
#          PLAYER_NAME                     Team Class Height Position  \
# 236  Ayanna Khalfani   UNC Greensboro (SoCon)   ---   5-11        G
#
#          PLAYER_ID        TEAM_NAME  GAMES  MINUTES_PLAYED  FIELD_GOALS_MADE  \
# 236  ncaaw.p.61460  N.C. Greensboro     31             911               139
#
#      ...  FREE_THROW_PERCENTAGE  OFFENSIVE_REBOUNDS  DEFENSIVE_REBOUNDS  \
# 236  ...                   60.0                  87                 126
#
#      TOTAL_REBOUNDS  ASSISTS  TURNOVERS  STEALS  BLOCKS  FOULS  POINTS
# 236             213      109         96      41      30     75     344
#
# [1 rows x 27 columns]

# %%
player_data.loc[player_data['PLAYER_NAME'] == 'Ayanna Khalfani', 'Class'] = 'Sr.'

# %%
player_data['Class'].unique()
# Out:
# array(['Jr.', 'So.', 'Sr.', 'Fr.'], dtype=object)

# %% [markdown]
# # Data Preprocessing
#
# ## Data Type Conversion

# %%
player_data.dtypes
# Out:
# PLAYER_NAME                object
# Team                       object
# Class                      object
# Height                     object
# Position                   object
# PLAYER_ID                  object
# TEAM_NAME                  object
# GAMES                       int64
# MINUTES_PLAYED              int64
# FIELD_GOALS_MADE            int64
# FIELD_GOAL_ATTEMPTS         int64
# FIELD_GOAL_PERCENTAGE     float64
# THREE_POINTS_MADE           int64
# THREE_POINT_ATTEMPTS        int64
# THREE_POINT_PERCENTAGE    float64
# FREE_THROWS_MADE            int64
# FREE_THROW_ATTEMPTS         int64
# FREE_THROW_PERCENTAGE     float64
# OFFENSIVE_REBOUNDS          int64
# DEFENSIVE_REBOUNDS          int64
# TOTAL_REBOUNDS              int64
# ASSISTS                     int64
# TURNOVERS                   int64
# STEALS                      int64
# BLOCKS                      int64
# FOULS                       int64
# POINTS                      int64
# dtype: object

# %% [markdown]
# ### Convert Numeric-only Columns

# %%
numeric_columns = ['GAMES', 'MINUTES_PLAYED', 'FIELD_GOALS_MADE', 'FIELD_GOAL_ATTEMPTS', 
                  'FIELD_GOAL_PERCENTAGE', 'THREE_POINTS_MADE', 'THREE_POINT_ATTEMPTS', 
                  'THREE_POINT_PERCENTAGE', 'FREE_THROWS_MADE', 'FREE_THROW_ATTEMPTS', 
                  'FREE_THROW_PERCENTAGE', 'OFFENSIVE_REBOUNDS', 'DEFENSIVE_REBOUNDS', 
                  'TOTAL_REBOUNDS', 'ASSISTS', 'TURNOVERS', 'STEALS', 'BLOCKS', 'FOULS', 'POINTS']

# %%
player_data[numeric_columns] = player_data[numeric_columns].apply(pd.to_numeric)
player_data.dtypes
# Out:
# PLAYER_NAME                object
# Team                       object
# Class                      object
# Height                     object
# Position                   object
# PLAYER_ID                  object
# TEAM_NAME                  object
# GAMES                       int64
# MINUTES_PLAYED              int64
# FIELD_GOALS_MADE            int64
# FIELD_GOAL_ATTEMPTS         int64
# FIELD_GOAL_PERCENTAGE     float64
# THREE_POINTS_MADE           int64
# THREE_POINT_ATTEMPTS        int64
# THREE_POINT_PERCENTAGE    float64
# FREE_THROWS_MADE            int64
# FREE_THROW_ATTEMPTS         int64
# FREE_THROW_PERCENTAGE     float64
# OFFENSIVE_REBOUNDS          int64
# DEFENSIVE_REBOUNDS          int64
# TOTAL_REBOUNDS              int64
# ASSISTS                     int64
# TURNOVERS                   int64
# STEALS                      int64
# BLOCKS                      int64
# FOULS                       int64
# POINTS                      int64
# dtype: object

# %%
player_data[player_data['THREE_POINT_PERCENTAGE'].isna()][['PLAYER_NAME', 'Team', 'Position', 'THREE_POINTS_MADE', 'THREE_POINT_ATTEMPTS', 'THREE_POINT_PERCENTAGE']].head()
# Out:
#          PLAYER_NAME                        Team Position  THREE_POINTS_MADE  \
# 245   Caitlin Weimar         Boston U. (Patriot)        F                  0
# 250        Abby Muse   Boise St. (Mountain West)        F                  0
# 254     Emily Bowman             Samford (SoCon)        C                  0
# 257  Christina Dalce        Villanova (Big East)        F                  0
# 258   Emily Saunders    Youngstown St. (Horizon)        F                  0
#
#      THREE_POINT_ATTEMPTS  THREE_POINT_PERCENTAGE
# 245                     0                     NaN
# 250                     0                     NaN
# 254                     0                     NaN
# 257                     0                     NaN
# 258                     0                     NaN

# %% [markdown]
# ### Convert Text-only Columns

# %%
string_columns = ['PLAYER_NAME', 'Team', 'Class', 'Height', 'Position', 'PLAYER_ID', 'TEAM_NAME']

# %%
player_data[string_columns].sample(10)
# Out:
#                 PLAYER_NAME                        Team Class Height Position  \
# 619       Taleah Washington                Wagner (NEC)   Sr.    5-7        G
# 571  Kirsten Lewis-Williams               Buffalo (MAC)   Fr.   5-10        G
# 424             Khalis Cain      UNC Greensboro (SoCon)   Sr.    6-3        F
# 70              Nitzan Amar            Manhattan (MAAC)   So.   5-10        G
# 775           Trinity Hardy   Army West Point (Patriot)   Jr.    5-8        G
# 798             Gabi Fields    Northern Colo. (Big Sky)   So.    5-5        G
# 552           Jillian Hayes         Cincinnati (Big 12)   Sr.    6-1        F
# 520   Honesty Scott-Grayson                Auburn (SEC)   Sr.    5-9        G
# 803           Teya Sidberry        Boston College (ACC)   So.    6-1        F
# 794            Emily Carver        App State (Sun Belt)   Jr.   5-10        G
#
#           PLAYER_ID          TEAM_NAME
# 619   ncaaw.p.60482             Wagner
# 571  ncaaw.p.112576            Buffalo
# 424   ncaaw.p.64664    N.C. Greensboro
# 70    ncaaw.p.67171          Manhattan
# 775   ncaaw.p.68094               Army
# 798   ncaaw.p.71666  Northern Colorado
# 552   ncaaw.p.64376         Cincinnati
# 520   ncaaw.p.56767             Auburn
# 803   ncaaw.p.71438       Boston Coll.
# 794   ncaaw.p.66617    Appalachian St.

# %%
player_data[string_columns] = player_data[string_columns].astype('string')
player_data[string_columns].dtypes
# Out:
# PLAYER_NAME    string[python]
# Team           string[python]
# Class          string[python]
# Height         string[python]
# Position       string[python]
# PLAYER_ID      string[python]
# TEAM_NAME      string[python]
# dtype: object

# %% [markdown]
# ## Value Substitution
#
# ### Substitute Abbreviated Position Names

# %%
player_data['Position'].unique()
# Out:
# <StringArray>
# ['G', 'F', 'C']
# Length: 3, dtype: string

# %%
position_names = {
    'F': 'Forward',
    'G': 'Guard',
    'C': 'Center'
}

# %%
player_data['Position'] = player_data['Position'].replace(position_names)
player_data['Position'].unique()
# Out:
# <StringArray>
# ['Guard', 'Forward', 'Center']
# Length: 3, dtype: string

# %% [markdown]
# ### Substitute Abbreviated Class Names

# %%
player_data['Class'].unique()
# Out:
# <StringArray>
# ['Jr.', 'So.', 'Sr.', 'Fr.']
# Length: 4, dtype: string

# %%
class_names = {
    'Fr.': 'Freshman',
    'So.': 'Sophomore',
    'Jr.': 'Junior',
    'Sr.': 'Senior'
}

# %%
player_data['Class'] = player_data['Class'].replace(class_names)
player_data['Class'].unique()
# Out:
# <StringArray>
# ['Junior', 'Sophomore', 'Senior', 'Freshman']
# Length: 4, dtype: string

# %% [markdown]
# ## Unit Conversion

# %%
def height_to_inches(height):
    feet, inches = map(int, height.split('-'))
    return feet * 12 + inches

# %%
player_data['Height'] = player_data['Height'].apply(height_to_inches)
player_data['Height'].unique()
# Out:
# array([67, 68, 62, 69, 66, 72, 70, 63, 71, 65, 64, 74, 73, 75, 76, 78, 77,
#        79, 80])

# %% [markdown]
# # Wrap Up

# %%
player_data.to_excel('player_data_clean.xlsx', index=False)
